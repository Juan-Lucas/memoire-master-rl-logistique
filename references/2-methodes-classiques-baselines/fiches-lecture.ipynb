# %% [markdown]
# ---
#
# ## 📄 Article 1 : Munirathinam & Yingling (1994)
#
# **Référence complète** :
# - Auteurs : Munirathinam, M. & Yingling, J.C.
# - Année : 1994
# - Titre : *A review of computer-based truck dispatching strategies for surface mining operations*
# - Source : [À compléter]
# - Fichier PDF : `A review of computer-based truck dispatching strategies for surface mining operations.pdf`
#
# **⭐ PRIORITÉ** : Article clé pour comprendre les heuristiques de base (tes futures baselines)
#
# ---
#
# ### ❓ Question 1 : Quel est le problème principal que cet article aborde ?
#
# **Réponse** :
#
# *[À compléter]*
#
# ---
#
# ### ❓ Question 2 : Comment les auteurs s'y prennent-ils pour l'analyser ?
#
# **Réponse** :
#
# *[À compléter — Ex : Ils passent en revue les heuristiques classiques : Fixed Truck Assignment, Minimize Waiting Time...]*
#
# ---
#
# ### ❓ Question 3 : Quelle est la conclusion principale ?
#
# **Réponse** :
#
# *[À compléter]*
#
# ---
#
# ### 🎯 Informations Spécifiques pour Baseline
#
# - **Algorithmes/Heuristiques mentionnés** : (liste)
# - **Métriques de performance utilisées** : (ex: temps de cycle, utilisation flotte...)
# - **Implémentation possible** : (facile/moyen/difficile)
# - **Code/Pseudo-code disponible** : Oui / Non
#
# ---
#
# ### ✅ Statut
#
# - [ ] Première lecture (Titre+Abstract+Conclusion)
# - [ ] Heuristiques identifiées et notées
# - [ ] Baseline implémentée
#
# **Date** : | **Temps** :

# %% [markdown]
# ---
#
# ## 📄 Article 2 : Subtil et al. (2011)
#
# **Référence complète** :
# - Auteurs : Subtil, R.F., Silva, D.M.J., Alves, J.C.L.
# - Année : 2011
# - Titre : *A Practical Approach to Truck Dispatch for Open Pit Mines*
# - Fichier PDF : `A Practical Approach to Truck Dispatch for Open Pit Mines.pdf`
#
# ---
#
# ### ❓ Question 1 : Quel est le problème principal ?
#
# *[À compléter]*
#
# ### ❓ Question 2 : Méthodologie ?
#
# *[À compléter — Ex : Approche hybride LP + Simulation]*
#
# ### ❓ Question 3 : Conclusion principale ?
#
# *[À compléter]*
#
# ---
#
# ### 🎯 Informations Spécifiques pour Baseline
#
# - **Algorithmes/Heuristiques** :
# - **Métriques** :
# - **Implémentation** :
# - **Code disponible** :
#
# ---
#
# ### ✅ Statut
#
# - [ ] Première lecture
# - [ ] Approche analysée
# - [ ] Baseline implémentée
#
# **Date** : | **Temps** :

# %% [markdown]
# ---
#
# ## 📄 Article 3 : Souza et al. (2010)
#
# **Référence complète** :
# - Auteurs : Souza, M.J.F. et al.
# - Année : 2010
# - Titre : *A hybrid heuristic algorithm for the open-pit-mining operational planning problem*
# - Fichier PDF : `A hybrid heuristic algorithm for the open-pit-mining operational planning problem.pdf`
#
# ---
#
# ### ❓ Question 1 : Quel est le problème principal ?
#
# *[À compléter]*
#
# ### ❓ Question 2 : Méthodologie ?
#
# *[À compléter — Ex : Métaheuristiques GRASP + VNS]*
#
# ### ❓ Question 3 : Conclusion principale ?
#
# *[À compléter]*
#
# ---
#
# ### 🎯 Informations Spécifiques pour Baseline
#
# - **Algorithmes/Heuristiques** :
# - **Métriques** :
# - **Implémentation** :
# - **Code disponible** :
#
# ---
#
# ### ✅ Statut
#
# - [ ] Première lecture
# - [ ] Approche analysée
#
# **Date** : | **Temps** :

# %% [markdown]
# ---
#
# ## 📄 Article 4 : Ahangaran et al. (2012)
#
# **Référence** :
# - Titre : *Real Time Dispatching Modelling For Trucks With Different Capacities In Open Pit Mines*
# - Fichier : `Real Time Dispatching Modelling For Trucks With Different Capacities In Open Pit Mines.pdf`
#
# ### ❓ Questions + 🎯 Baseline Info
#
# *[Structure identique — à compléter]*
#
# ---
#
# ## 📄 Article 5 : Ta et al. (2013)
#
# **Référence** :
# - Titre : *A linear model for surface mining haul truck allocation incorporating shovel idle probabilities*
# - Fichier : `A linear model for surface mining haul truck allocation incorporating shovel idle probabilities.pdf`
#
# ### ❓ Questions + 🎯 Baseline Info
#
# *[À compléter]*
#
# ---
#
# ## 📄 Article 6 : Wang (2022)
#
# **Référence** :
# - Titre : *Truck Dispatching Optimization Model and Algorithm Based on 0-1 Decision Variables*
# - Fichier : `Truck Dispatching Optimization Model and Algorithm Based on 0-1 Decision Variables.pdf`
#
# ### ❓ Questions + 🎯 Baseline Info
#
# *[À compléter]*

# %% [markdown]
# ---
#
# ## 📊 Tableau Comparatif des Méthodes Classiques
#
# | Article | Approche | Algorithme | Métriques | Complexité | Implémentable |
# |---------|----------|------------|-----------|------------|---------------|
# | Munirathinam (1994) | Heuristiques | [À remplir] | [À remplir] | Faible | ✅ |
# | Subtil (2011) | Hybride LP+Sim | [À remplir] | [À remplir] | Moyenne | ⚠️ |
# | Souza (2010) | Métaheuristiques | GRASP/VNS | [À remplir] | Élevée | ⚠️ |
# | Ahangaran (2012) | MILP | [À remplir] | [À remplir] | Élevée | ❌ |
# | Ta (2013) | LP + Probabilités | [À remplir] | [À remplir] | Moyenne | ⚠️ |
# | Wang (2022) | 0-1 Variables | [À remplir] | [À remplir] | [À remplir] | [À remplir] |
#
# ---
#
# ## 🎯 Sélection des Baselines pour Implémentation
#
# Après lecture de ces articles, sélectionner **2-3 approches** à implémenter comme baselines :
#
# 1. **Baseline Simple** : [Article choisi] — Heuristique facile à coder
# 2. **Baseline Intermédiaire** : [Article choisi] — Approche classique robuste
# 3. **Baseline Avancée** : [Article choisi] — État de l'art non-RL
#
# **Critères de sélection** :
# - ✅ Faisabilité technique (temps d'implémentation)
# - ✅ Représentativité (approche reconnue dans la littérature)
# - ✅ Comparabilité (mêmes métriques que ton agent RL)
