# %% [markdown]
# ---
#
# ## 📄 Article 1 : Ozdemir & Kumral (2019)
#
# **Référence** :
# - Titre : *Simulation based optimization of truck shovel material handling systems in multi pit surface mines*
# - Fichier : `Simulation based optimization of truck shovel material handling systems in multi pit surface mines.pdf`
#
# ---
#
# ### 📊 Résultats Clés
#
# **Métriques utilisées** :
# - *[Ex : Productivité (t/h), utilisation flotte (%), coût ($/t)...]*
#
# **Chiffres importants** :
# - Amélioration de **X%** par rapport à *[baseline]*
# - Temps de calcul : *[X secondes/minutes]*
# - *[Autres résultats quantitatifs]*
#
# ---
#
# ### ⚠️ Limites Identifiées
#
# **Ce qui ne fonctionne pas bien** :
# - *[Ex : Ne gère pas bien l'incertitude, suppose des conditions stables...]*
#
# **Hypothèses simplificatrices** :
# - *[Ex : Routes parfaites, pas de dégradation...]*
#
# ---
#
# ### 💡 Ce que je peux en tirer pour mon projet
#
# **Insights pratiques** :
# 1. *[Ex : Le "match factor" est un KPI important à suivre]*
# 2. *[À compléter]*
#
# **Métriques à réutiliser** :
# - *[Liste des métriques pertinentes pour ma comparaison]*
#
# ---
#
# ### ✅ Statut
#
# - [ ] Lecture rapide (30 min)
# - [ ] Résultats extraits
# - [ ] Métriques ajoutées au tableau comparatif
#
# **Date** : | **Temps** :

# %% [markdown]
# ---
#
# ## 📄 Article 2 : Abolghasemian et al. (2020)
#
# **Référence** :
# - Titre : *A Two-Phase Simulation-Based Optimization of Hauling System in Open-Pit Mine*
# - Fichier : `A Two-Phase Simulation-Based Optimization of Hauling System in Open-Pit Mine.pdf`
#
# ---
#
# ### 📊 Résultats Clés
#
# *[Structure identique — à compléter]*
#
# ### ⚠️ Limites
#
# *[À compléter]*
#
# ### 💡 Insights
#
# *[À compléter]*
#
# ---
#
# ### ✅ Statut
#
# - [ ] Lecture rapide
# - [ ] Résultats extraits
#
# **Date** : | **Temps** :

# %% [markdown]
# ---
#
# ## 📄 Article 3 : Concurrent Simulation And Optimization
#
# **Fichier** : `Concurrent Simulation And Optimization Models For Mining Planning.pdf`
#
# ### 📊 Résultats + ⚠️ Limites + 💡 Insights
#
# *[À compléter]*
#
# ---
#
# ## 📄 Article 4 : Simulation and optimization approach for uncertainty
#
# **Fichier** : `Simulation and optimization approach for uncertainty based short-term planning in open pit mines.pdf`
#
# **🎯 FOCUS** : Gestion de l'incertitude (pertinent pour mon approche RL adaptative)
#
# ### 📊 Résultats + ⚠️ Limites + 💡 Insights
#
# *[À compléter]*
#
# ---
#
# ## 📄 Article 5 : Open Pit Truck Shovel Haulage System Simulation
#
# **Fichier** : `Open Pit Truck Shovel Haulage System Simulation.pdf`
#
# ### 📊 Résultats + ⚠️ Limites + 💡 Insights
#
# *[À compléter]*
#
# ---
#
# ## 📄 Article 6 : A simulation model to study truck allocation
#
# **Fichier** : `A simulation model to study truckallocation options.pdf`
#
# ### 📊 Résultats + ⚠️ Limites + 💡 Insights
#
# *[À compléter]*
#
# ---
#
# ## 📄 Article 7 : Truck dispatching in an open pit mine
#
# **Fichier** : `Truck dispatching in an open pit mine.pdf`
#
# ### 📊 Résultats + ⚠️ Limites + 💡 Insights
#
# *[À compléter]*
#
# ---
#
# ## 📄 Article 8 : Use of Machine Learning Algorithm Models
#
# **Fichier** : `Use of Machine Learning Algorithm Models to Optimize the Fleet Management System in Opencast Mines.pdf`
#
# **🎯 FOCUS** : Machine Learning (non-RL) pour FMS — Comparaison intéressante
#
# ### 📊 Résultats + ⚠️ Limites + 💡 Insights
#
# *[À compléter]*

# %% [markdown]
# ---
#
# ## 📊 Tableau Récapitulatif — Résultats Chiffrés
#
# | Article | Approche | Métriques | Amélioration | Limites Principales |
# |---------|----------|-----------|--------------|---------------------|
# | Ozdemir (2019) | SimOpt | [À remplir] | +X% productivité | [À remplir] |
# | Abolghasemian (2020) | Two-Phase | [À remplir] | [À remplir] | [À remplir] |
# | Concurrent SimOpt | [À remplir] | [À remplir] | [À remplir] | [À remplir] |
# | Uncertainty approach | [À remplir] | [À remplir] | [À remplir] | [À remplir] |
# | Truck Shovel Sim | [À remplir] | [À remplir] | [À remplir] | [À remplir] |
# | Truck allocation | [À remplir] | [À remplir] | [À remplir] | [À remplir] |
# | Truck dispatching | [À remplir] | [À remplir] | [À remplir] | [À remplir] |
# | ML for FMS | [À remplir] | [À remplir] | [À remplir] | [À remplir] |
#
# ---
#
# ## 💡 Synthèse des Limites Communes
#
# Après lecture de ces études de cas, identifier les limites récurrentes des approches classiques :
#
# ### ⚠️ Problèmes Identifiés
#
# 1. **Incapacité à gérer l'incertitude dynamique** :
#    - *[Articles qui mentionnent ce problème : ...]*
#    - **→ Opportunité pour mon RL** : L'agent peut s'adapter en temps réel
#
# 2. **Optimisation locale vs globale** :
#    - *[Articles : ...]*
#    - **→ Opportunité RL** : Optimisation holistique de la flotte
#
# 3. **Hypothèses simplificatrices (routes parfaites, conditions stables)** :
#    - *[Articles : ...]*
#    - **→ Opportunité RL** : Simulation réaliste avec dégradation, météo, trafic
#
# 4. **Temps de calcul élevé (pour optimisation exacte)** :
#    - *[Articles : ...]*
#    - **→ Opportunité RL** : Inférence rapide après entraînement
#
# 5. **Manque d'apprentissage continu** :
#    - *[Articles : ...]*
#    - **→ Opportunité RL** : Amélioration continue avec nouvelles données
#
# ---
#
# ## 🎯 Utilisation dans Mon Mémoire
#
# Ces limites identifiées vont nourrir :
#
# ### Chapitre 1 — Problématique
# - Citer ces limites pour justifier l'approche RL
# - Exemple : "Comme le montre Ozdemir & Kumral (2019), les approches SimOpt peinent à..."
#
# ### Chapitre 4 — Discussion
# - Comparer mes résultats avec ces chiffres
# - Montrer que le RL surmonte ces limites spécifiques
#
# ### Tableau Comparatif Final (Chapitre 4)
#
# | Approche | Adaptabilité | Temps calcul | Gestion incertitude | Apprentissage | Performance |
# |----------|--------------|--------------|---------------------|---------------|-------------|
# | Heuristiques | ❌ | ✅ Rapide | ❌ | ❌ | Baseline |
# | MILP | ❌ | ❌ Lent | ❌ | ❌ | Optimal (petites instances) |
# | SimOpt | ⚠️ Limitée | ⚠️ Moyen | ⚠️ Partielle | ❌ | Bon |
# | **Mon RL** | ✅ | ✅ (après training) | ✅ | ✅ | **[À démontrer]** |
#
# ---
#
# ## ✅ Checklist Globale
#
# - [ ] Les 8 articles lus en mode "rapide/ciblé"
# - [ ] Tableau récapitulatif complété
# - [ ] Limites communes identifiées et synthétisées
# - [ ] Opportunités pour RL listées
# - [ ] Métriques pertinentes collectées pour comparaison future
