# %% [markdown]
# ---
#
# ## 📄 Article 1 : Afrapoli & Askari-Nasab (2017)
#
# **Référence complète** :
# - Auteurs : Afrapoli, A.M. & Askari-Nasab, H.
# - Année : 2017
# - Titre : *Mining fleet management systems: a review of models and algorithms*
# - Source : International Journal of Mining, Reclamation and Environment
# - Fichier PDF : `Mining fleet management systems a review of models and algorithms.pdf`
#
# ---
#
# ### ❓ Question 1 : Quel est le problème principal que cet article aborde ?
#
# **Réponse** (2-3 phrases, avec tes propres mots) :
#
# *L’article examine les modèles et algorithmes utilisés dans les systèmes de gestion de flottes minières, en cherchant à comprendre leurs fondements et à identifier les lacunes dans la littérature. Il vise à clarifier les enjeux liés à la planification opérationnelle intégrée, la simulation et l’optimisation dans le contexte minier.*
#
# ---
#
# ### ❓ Question 2 : Comment les auteurs s'y prennent-ils pour l'analyser ?
#
# **Réponse** (2-3 phrases) :
#
# *Les auteurs passent en revue les systèmes industriels et académiques de gestion de flotte, en classant les principaux algorithmes selon trois problématiques : le chemin le plus court, l’optimisation de la production et la répartition en temps réel. Ils analysent les stratégies multi-étapes et à étape unique, et discutent les limites pratiques et théoriques des approches existantes.*
#
# ---
#
# ### ❓ Question 3 : Quelle est la conclusion principale ?
#
# **Réponse** (2-3 phrases) :
#
# *L’article conclut que, malgré les avancées, il existe des lacunes importantes dans les modèles actuels, notamment la prise en compte de l’incertitude, la connexion entre plans stratégiques et opérationnels, et la gestion dynamique des flottes à grande échelle. Les auteurs recommandent d’intégrer des méthodes d’optimisation basées sur la simulation et des algorithmes de répartition en temps réel pour améliorer la gestion des flottes minières.*
#
# ---
#
# ### 📌 Notes Complémentaires (optionnel)
#
# - **Figures/Tableaux clés** : (numéros et description rapide)
# - **Citations utiles** : (pages + extraits pertinents)
# - **Connexions avec d'autres articles** : Lien direct avec les travaux sur la planification dynamique et l’optimisation en simulation minière.
# - **Points à approfondir** : Approche GP, gestion des incertitudes, impact des déplacements de pelles.
#
# ---
#
# ### ✅ Statut de Lecture
#
# - [x] Titre + Abstract + Conclusion lus
# - [ ] Lecture approfondie (si nécessaire)
# - [ ] Intégré dans le mémoire (Chapitre X)
#
# **Date de lecture** : 17/01/2026
#
# **Temps passé** : 60 minutes

# %% [markdown]
# ---
#
# ## 📄 Article 2 : Alarie & Gamache (2002)
#
# **Référence complète** :
# - Auteurs : Alarie, S. & Gamache, M.
# - Année : 2002
# - Titre : *Overview of Solution Strategies Used in Truck Dispatching Systems for Open Pit Mines*
# - Source : International Journal of Surface Mining, Reclamation and Environment
# - Fichier PDF : `Overview of Solution Strategies Used in Truck Dispatching Systems for Open Pit Mines.pdf`
#
# ---
#
# ### ❓ Question 1 : Quel est le problème principal que cet article aborde ?
#
# **Réponse** (2-3 phrases, avec tes propres mots) :
#
# *L’article traite des systèmes de répartition des camions dans les mines à ciel ouvert. Il analyse les différentes stratégies existantes pour résoudre le problème de la répartition, en mettant en avant les défis liés à l’optimisation des affectations de camions dans un environnement minier dynamique.*
#
# ---
#
# ### ❓ Question 2 : Comment les auteurs s'y prennent-ils pour l'analyser ?
#
# **Réponse** (2-3 phrases) :
#
# *Les auteurs passent en revue les approches classiques et récentes de répartition, en comparant les stratégies à étape unique et multi-étapes. Ils discutent les avantages, limites et évolutions possibles de chaque méthode, tout en intégrant les apports des nouvelles technologies (GPS, moniteurs embarqués) pour améliorer la prise de décision en temps réel.*
#
# ---
#
# ### ❓ Question 3 : Quelle est la conclusion principale ?
#
# **Réponse** (2-3 phrases) :
#
# *L’article conclut qu’un système de répartition idéal devrait s’appuyer sur une approche multi-étapes, capable d’intégrer de nombreuses contraintes opérationnelles et de s’adapter rapidement aux changements grâce aux technologies modernes. L’intégration du GPS, des moniteurs embarqués et de la collecte de données en temps réel permet d’optimiser la gestion des camions et d’améliorer la qualité des décisions de répartition.*
#
# ---
#
# ### 📌 Notes Complémentaires (optionnel)
#
# - **Figures/Tableaux clés** :
# - **Citations utiles** :
# - **Connexions avec d'autres articles** : Lien direct avec les travaux sur la répartition dynamique et l’intégration des technologies embarquées.
# - **Points à approfondir** : Formulations mathématiques avancées, gestion des contraintes de mélange, impact des nouvelles technologies.
#
# ---
#
# ### ✅ Statut de Lecture
#
# - [x] Titre + Abstract + Conclusion lus
# - [ ] Lecture approfondie (si nécessaire)
# - [ ] Intégré dans le mémoire
#
# **Date de lecture** : 17/01/2026
#
# **Temps passé** : 60 minutes

# %% [markdown]
# ---
#
# ## 📄 Article 3 : Newman et al. (2010)
#
# **Référence complète** :
# - Auteurs : Newman, A.M., Rubio, E., Caro, R., Weintraub, A., et al.
# - Année : 2010
# - Titre : *A Review of Operations Research in Mine Planning*
# - Source : Interfaces
# - Fichier PDF : `A Review of Operations Research in Mine Planning.pdf`
#
# **Note** : Article de contexte global — Lecture en **survol** (10-15 min max)
#
# ---
#
# ### ❓ Question 1 : Quel est le problème principal que cet article aborde ?
#
# **Réponse** (2-3 phrases, avec tes propres mots) :
#
# *L’article propose une revue globale des applications de la recherche opérationnelle (RO) dans la planification minière, couvrant aussi bien les mines à ciel ouvert que souterraines. Il met l’accent sur l’évolution des méthodes d’optimisation et de simulation pour résoudre des problèmes complexes liés à la conception, la planification de la production, la sélection et la répartition des équipements.*
#
# ---
#
# ### ❓ Question 2 : Comment les auteurs s'y prennent-ils pour l'analyser ?
#
# **Réponse** (2-3 phrases) :
#
# *Les auteurs passent en revue plusieurs décennies de littérature, en mettant en avant les travaux récents, les domaines émergents et les succès industriels. Ils illustrent les avancées par des études de cas, discutent les limites des approches traditionnelles et présentent les nouvelles tendances, notamment l’intégration de l’incertitude et la résolution de modèles plus réalistes et détaillés.*
#
# ---
#
# ### ❓ Question 3 : Quelle est la conclusion principale ?
#
# **Réponse** (2-3 phrases) :
#
# *L’article conclut que la recherche opérationnelle joue un rôle clé dans la planification minière, avec une tendance vers des modèles plus grands, plus complexes et plus rapides à résoudre grâce aux progrès technologiques. L’intégration de l’incertitude, l’approche holistique de la chaîne de valeur et la collaboration accrue entre chercheurs et industriels sont des axes majeurs pour l’avenir du secteur.*
#
# ---
#
# ### 📌 Notes Complémentaires (optionnel)
#
# - **Figures/Tableaux clés** :
# - **Citations utiles** :
# - **Connexions avec d'autres articles** : Lien direct avec les travaux sur la planification stochastique, l’optimisation et la simulation minière.
# - **Points à approfondir** : Modèles de transition ciel ouvert/souterrain, intégration de l’incertitude, optimisation de la chaîne d’approvisionnement.
#
# ---
#
# ### ✅ Statut de Lecture
#
# - [x] Titre + Abstract + Conclusion lus
# - [ ] Lecture approfondie (si nécessaire)
# - [ ] Intégré dans le mémoire
#
# **Date de lecture** : 17/01/2026
#
# **Temps passé** : 30 minutes

# %% [markdown]
# ---
#
# ## 📄 Article 4 : Mohtasham et al. (2023)
#
# **Référence complète** :
# - Auteurs : Mohtasham, M. et al.
# - Année : 2023
# - Titre : *Evaluating the performance of the DISPATCH algorithm, a commercial software, in the Sungun copper mine*
# - Source : Journal of Geomines
# - Fichier PDF : `Evaluating the performance of the DISPATCH algorithm, a commercial software, in the Sungun copper mine.pdf`
#
# ---
#
# ### ❓ Question 1 : Quel est le problème principal que cet article aborde ?
#
# **Réponse** (2-3 phrases, avec tes propres mots) :
#
# *L’article s’intéresse à l’efficacité des systèmes de gestion de flotte intelligents dans les mines à ciel ouvert, en particulier à l’implémentation et l’évaluation de l’algorithme DISPATCH dans la mine de cuivre de Sungun en Iran. Il vise à démontrer comment l’adoption de tels systèmes peut améliorer la productivité et réduire les coûts par rapport aux méthodes traditionnelles de répartition.*
#
# ---
#
# ### ❓ Question 2 : Comment les auteurs s'y prennent-ils pour l'analyser ?
#
# **Réponse** (2-3 phrases) :
#
# *Les auteurs construisent un modèle de simulation à événements discrets dans le logiciel Arena, basé sur les données réelles de la mine. Ils comparent la performance du système DISPATCH à celle de la stratégie de répartition actuelle, en mesurant des indicateurs comme le taux de production, l’efficacité de la flotte et le temps d’attente.*
#
# ---
#
# ### ❓ Question 3 : Quelle est la conclusion principale ?
#
# **Réponse** (2-3 phrases) :
#
# *L’étude montre que l’algorithme DISPATCH permet d’augmenter la productivité de la flotte de 17,4 % par rapport à la méthode traditionnelle, tout en réduisant les temps d’attente et les coûts opérationnels. Les auteurs concluent que l’adoption de systèmes de gestion de flotte intelligents pourrait significativement améliorer l’efficacité des mines iraniennes.*
#
# ---
#
# ### 📌 Notes Complémentaires (optionnel)
#
# - **Figures/Tableaux clés** :
# - **Citations utiles** :
# - **Connexions avec d'autres articles** : Lien avec les études sur la gestion intelligente de flotte et la simulation minière.
# - **Points à approfondir** : Détails du modèle multi-objectifs, limites de la simulation, généralisation à d’autres mines.
#
# ---
#
# ### ✅ Statut de Lecture
#
# - [x] Titre + Abstract + Conclusion lus
# - [ ] Lecture approfondie (si nécessaire)
# - [ ] Intégré dans le mémoire
#
# **Date de lecture** : 17/01/2026
#
# **Temps passé** : 60 minutes

# %% [markdown]
# ---
#
# ## 📊 Tableau Récapitulatif des Lectures
#
# | Article | Priorité | Statut | Date | Temps | Notes |
# |---------|----------|--------|------|-------|-------|
# | Afrapoli & Askari-Nasab (2017) | ⭐⭐⭐ | 🔄 En cours (Titre+Abstract+Conclusion) | 17/01/2026 | 60 minutes | Survol |
# | Alarie & Gamache (2002) | ⭐⭐ | 🔄 En cours (Titre+Abstract+Conclusion) | 17/01/2026 | 60 minutes | Survol |
# | Newman et al. (2010) | ⭐ | 🔄 En cours (Titre+Abstract+Conclusion) | 17/01/2026 | 30 minutes | Survol |
# | Mohtasham et al. (2023) | ⭐ | 🔄 En cours (Titre+Abstract+Conclusion) | 17/01/2026 | 60 minutes | Survol |
#
# **Légende** :
# - ⬜ Pas commencé
# - 🔄 En cours (Titre+Abstract+Conclusion)
# - ✅ Première lecture complétée
# - ✅✅ Lecture approfondie complétée
#
# ---
#
# ## 🎯 Plan d'Action (7 jours)
#
# - **Jour 1** : Afrapoli & Askari-Nasab (2017) — 1h max
# - **Jour 2** : Alarie & Gamache (2002) — 1h max
# - **Jour 3** : Newman et al. (2010) — 30 min (survol)
# - **Jour 4** : Mohtasham et al. (2023) — 1h max
# - **Jour 5-7** : Commencer les articles du dossier 3 (RL)
#
# ---
#
# ## 💡 Rappel Méthodologique
#
# **Ce qu'il faut faire** :
# - ✅ Lire Titre + Abstract + Conclusion UNIQUEMENT
# - ✅ Répondre aux 3 questions en 2-3 phrases
# - ✅ Limiter à 1 heure MAX par article
# - ✅ Scanner les figures/tableaux rapidement
#
# **Ce qu'il NE FAUT PAS faire** :
# - ❌ Lire l'article en entier au premier passage
# - ❌ Essayer de tout comprendre immédiatement
# - ❌ Prendre des notes trop détaillées
# - ❌ Se perdre dans les équations techniques
#
# **Règle d'or** : "Capturer" d'abord, "Approfondir" après !
